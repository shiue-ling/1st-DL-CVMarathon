# %%
from ssd import build_ssd
from layers.box_utils import *
from torch.autograd import Variable
from layers import box_utils
from layers import Detect
#     def __init__(self):
#-         self.label_map = get_label_map(osp.join(COCO_ROOT, 'coco_labels.txt'))
#+         here = osp.dirname(__file__)
#+         self.label_map = get_label_map(osp.join(here, 'coco_labels.txt'))
from layers import functions
from layers import modules
from math import sqrt as sqrt
from itertools import product as product
from torch.autograd import Function
from layers.box_utils import decode, nms

# %%
import os
import sys
import torch
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn
import torch.nn.init as init
import torch.utils.data as data
import numpy as np
import argparse
import torchvision
import pickle
import torch.nn.functional as F

# %%
## 詳細模型結構可以參考ssd.py
ssd_net=build_ssd('train', size=300, num_classes=21)
ssd_net.load_weights('./demo/ssd300_mAP_77.43_v2.pth')
# Out:
# Loading weights into state dict...
# Finished!

# %% [markdown]
# ## 默認Config檔案在data/config.py內

# %%
ssd_net.cfg
# Out:
# {'num_classes': 21,
#  'lr_steps': (80000, 100000, 120000),
#  'max_iter': 120000,
#  'feature_maps': [38, 19, 10, 5, 3, 1],
#  'min_dim': 300,
#  'steps': [8, 16, 32, 64, 100, 300],
#  'min_sizes': [30, 60, 111, 162, 213, 264],
#  'max_sizes': [60, 111, 162, 213, 264, 315],
#  'aspect_ratios': [[2], [2, 3], [2, 3], [2, 3], [2], [2]],
#  'variance': [0.1, 0.2],
#  'clip': True,
#  'name': 'VOC'}

# %%
cfg = {
    'num_classes': 21,
    'lr_steps': (80000, 100000, 120000),
    'max_iter': 120000,
    'feature_maps': [38, 19, 10, 5, 3, 1],
    'min_dim': 300,
    'steps': [8, 16, 32, 64, 100, 300],
    'min_sizes': [30, 60, 111, 162, 213, 264],
    'max_sizes': [60, 111, 162, 213, 264, 315],
    'aspect_ratios': [[2], [2, 3], [2, 3], [2, 3], [2], [2]],
    'variance': [0.1, 0.2],
    'clip': True,
    'name': 'VOC',
}

# %% [markdown]
# ### 'aspect_ratios' : 使用六張Feature Map，每一張上方有預設的anchor boxes，Boxes aspect ratio可以自己設定
# ### 'feature_maps' : 使用feature map大小為[38x38, 19x19, 10x10, 5x5, 3x3, 1x1]
# ### 'min_sizes'、'max_sizes'可藉由下方算式算出，由作者自行設計
# ### 'steps' : Feature map回放回原本300*300的比例，如38要回放為300大概就是8倍
# ### 'variance' : Training 的一個trick，加速收斂，詳見：https://github.com/rykov8/ssd_keras/issues/53

# %% [markdown]
# ---

# %% [markdown]
# ## 'min_sizes'、'max_sizes' 計算

# %%
import math
## source:https://blog.csdn.net/gbyy42299/article/details/81235891
min_dim = 300   ## 维度
# conv4_3 ==> 38 x 38
# fc7 ==> 19 x 19
# conv6_2 ==> 10 x 10
# conv7_2 ==> 5 x 5
# conv8_2 ==> 3 x 3
# conv9_2 ==> 1 x 1
mbox_source_layers = ['conv4_3', 'fc7', 'conv6_2', 'conv7_2', 'conv8_2', 'conv9_2'] ## prior_box來源層，可以更改。很多改進都是基於此處的調整。
# in percent %
min_ratio = 20 ## 這裡即是論文中所說的Smin的= 0.2，Smax的= 0.9的初始值，經過下面的運算即可得到min_sizes，max_sizes。
max_ratio = 90
step = int(math.floor((max_ratio - min_ratio) / (len(mbox_source_layers) - 2)))## 取一個間距步長，即在下面用於循環給比取值時起一個間距作用。可以用一個具體的數值代替，這裡等於17。
min_sizes = []  ## 經過以下運算得到min_sizes和max_sizes。
max_sizes = []
for ratio in range(min_ratio, max_ratio + 1, step):
    ## 從min_ratio至max_ratio + 1每隔步驟= 17取一個值賦值給比。注意範圍函數的作用。
    ## min_sizes.append（）函數即把括號內部每次得到的值依次給了min_sizes。
    min_sizes.append(min_dim * ratio / 100.)
    max_sizes.append(min_dim * (ratio + step) / 100.)
min_sizes = [min_dim * 10 / 100.] + min_sizes
max_sizes = [min_dim * 20 / 100.] + max_sizes

## steps: 這一步要仔細理解，即計算卷積層產生的prior_box距離原圖的步長，先驗框中心點的坐標會乘以step，
## 相當於從特徵映射位置映射回原圖位置，比如conv4_3輸出特徵圖大小為38 *38，而輸入的圖片為300* 300，
## 所以38 *8約等於300，所以映射步長為8.這是針對300* 300的訓練圖片。
steps = [8, 16, 32, 64, 100, 300]  
aspect_ratios = [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
 
print('min_sizes: ',min_sizes)
print('max_sizes: ',max_sizes)
# Out:
# min_sizes:  [30.0, 60.0, 111.0, 162.0, 213.0, 264.0]
# max_sizes:  [60.0, 111.0, 162.0, 213.0, 264.0, 315.0]

# %% [markdown]
# ---

# %% [markdown]
# ## Default anchor boxes設計原理，看懂收穫很多
# ##### 可以理解 SSD原文中 8732個anchors是怎麼來的
# ##### 38×38×4+19×19×6+10×10×6+5×5×6+3×3×4+1×1×4=8732

# %%
class PriorBox(object):
    """Compute priorbox coordinates in center-offset form for each source
    feature map.
    """
    def __init__(self, cfg):
        super(PriorBox, self).__init__()
        self.image_size = cfg['min_dim']
        # number of priors for feature map location (either 4 or 6)
        self.num_priors = len(cfg['aspect_ratios'])
        self.variance = cfg['variance'] or [0.1]
        self.feature_maps = cfg['feature_maps']
        self.min_sizes = cfg['min_sizes']
        self.max_sizes = cfg['max_sizes']
        self.steps = cfg['steps']
        self.aspect_ratios = cfg['aspect_ratios']
        self.clip = cfg['clip']
        self.version = cfg['name']
        for v in self.variance:
            if v <= 0:
                raise ValueError('Variances must be greater than 0')

    def forward(self):
        mean = []
        '''依照Feature map大小找出所有的pixel 中心'''
        '''下方這兩個loop會找出W個x軸pixel對上W個y軸pixel，假如現在是在38x38的feature map上，就會有38x38個值'''
        '''ex. [0,1],[0,2]..[0,37] [1,1],[1,2]..[1,37]..........[37,37]'''
        for k, f in enumerate(self.feature_maps):
            for i, j in product(range(f), repeat=2):
                f_k = self.image_size / self.steps[k] ## 如self.steps==8，就是先將原圖size normalize(/300)後再乘上8
                # unit center x,y
                '''中心點'''
                cx = (j + 0.5) / f_k
                cy = (i + 0.5) / f_k

                # aspect_ratio: 1
                # rel size: min_size
                '''/self.image_size 就是在做normalization '''
                s_k = self.min_sizes[k]/self.image_size
                '''小的正方形box'''
                mean += [cx, cy, s_k, s_k]

                # aspect_ratio: 1
                # rel size: sqrt(s_k * s_(k+1))
                '''大的正方形box'''
                s_k_prime = sqrt(s_k * (self.max_sizes[k]/self.image_size))
                mean += [cx, cy, s_k_prime, s_k_prime]

                # rest of aspect ratios
                for ar in self.aspect_ratios[k]:
                    '''aspect ratio 2,3'''
                    mean += [cx, cy, s_k*sqrt(ar), s_k/sqrt(ar)]
                    '''aspect ratio 1/2,1/3'''
                    mean += [cx, cy, s_k/sqrt(ar), s_k*sqrt(ar)]
        # back to torch land
        output = torch.Tensor(mean).view(-1, 4)
        if self.clip:
            output.clamp_(max=1, min=0)
        return output

# %%
PriorBox_Demo=PriorBox(cfg)

# %%
print(PriorBox_Demo.forward().shape)
# Out:
# torch.Size([8732, 4])

# %% [markdown]
# ---

# %% [markdown]
# ## Loss 如何設計

# %%
class MultiBoxLoss(nn.Module):

    def __init__(self, num_classes, overlap_thresh, prior_for_matching,
                 bkg_label, neg_mining, neg_pos, neg_overlap, encode_target,
                 use_gpu=True):
        super(MultiBoxLoss, self).__init__()
        self.use_gpu = use_gpu
        '''有幾類'''
        self.num_classes = num_classes
        '''判定為正樣本的threshold，一般設為0.5'''
        self.threshold = overlap_thresh
        '''background自己會有一類，不用Label，假如我們有20類一樣標註0-19，下方會自己空出一類給background'''
        self.background_label = bkg_label
        self.encode_target = encode_target
        self.use_prior_for_matching = prior_for_matching
        '''OHEM，找出分得最不好的樣品，也就是confidence score比較低的正負樣品'''
        self.do_neg_mining = neg_mining
        '''負樣品與正樣品的比例，通常是3:1'''
        self.negpos_ratio = neg_pos
        self.neg_overlap = neg_overlap
        self.variance = cfg['variance']
     

    def forward(self, predictions, targets):

        '''prediction會output三個值'''
        '''loc shape: bounding box 資訊，torch.size(batch_size,num_priors,4)'''
        '''conf shape: 每一個bounding box 的信心程度，torch.size(batch_size,num_priors,num_classes)'''
        '''priors shape: 預設的defaul box， torch.size(num_priors,4)'''
        loc_data, conf_data, priors = predictions
        num = loc_data.size(0)
        priors = priors[:loc_data.size(1), :]
        num_priors = (priors.size(0))
        num_classes = self.num_classes

        # match priors (default boxes) and ground truth boxes
        loc_t = torch.Tensor(num, num_priors, 4)
        conf_t = torch.LongTensor(num, num_priors)
        for idx in range(num):
            truths = targets[idx][:, :-1].data
            labels = targets[idx][:, -1].data
            defaults = priors.data
            '''jaccard 計算每一個BBOX與ground truth的IOU'''
            match(self.threshold, truths, defaults, self.variance, labels,
                  loc_t, conf_t, idx)
        if self.use_gpu:
            loc_t = loc_t.cuda()
            conf_t = conf_t.cuda()
        '''用Variable包裝'''
        loc_t = Variable(loc_t, requires_grad=False)
        conf_t = Variable(conf_t, requires_grad=False)

        pos = conf_t > 0
        num_pos = pos.sum(dim=1, keepdim=True)


        pos_idx = pos.unsqueeze(pos.dim()).expand_as(loc_data)
        loc_p = loc_data[pos_idx].view(-1, 4)
        loc_t = loc_t[pos_idx].view(-1, 4)
        '''smooth_l1_loss 計算bounding box regression'''
        loss_l = F.smooth_l1_loss(loc_p, loc_t, size_average=False)

        # Compute max conf across batch for hard negative mining
        batch_conf = conf_data.view(-1, self.num_classes)
        loss_c = log_sum_exp(batch_conf) - batch_conf.gather(1, conf_t.view(-1, 1))

        # Hard Negative Mining
        loss_c = loss_c.view(num, -1)
        loss_c[pos] = 0
        '''排列confidence 的分數'''
        _, loss_idx = loss_c.sort(1, descending=True)
        _, idx_rank = loss_idx.sort(1)
        num_pos = pos.long().sum(1, keepdim=True)
        '''負樣品取出數量 == negpos_ratio*num_pos'''
        num_neg = torch.clamp(self.negpos_ratio*num_pos, max=pos.size(1)-1)
        neg = idx_rank < num_neg.expand_as(idx_rank)

        # Confidence Loss Including Positive and Negative Examples
        pos_idx = pos.unsqueeze(2).expand_as(conf_data)
        neg_idx = neg.unsqueeze(2).expand_as(conf_data)
        conf_p = conf_data[(pos_idx+neg_idx).gt(0)].view(-1, self.num_classes)
        targets_weighted = conf_t[(pos+neg).gt(0)]
        '''用cross_entropy做分類'''
        loss_c = F.cross_entropy(conf_p, targets_weighted, size_average=False)

        # Sum of losses: L(x,c,l,g) = (Lconf(x, c) + αLloc(x,l,g)) / N
        #double轉成torch.float64
        N = num_pos.data.sum().double()
        loss_l = loss_l.double()
        loss_c = loss_c.double()
        loss_l /= N
        loss_c /= N
        return loss_l, loss_c

# %% [markdown]
# ## 產生我們Loss function，注意這裡的class要包含背景

# %%
'''要不要使用gpu'''
Use_cuda=True
criterion = MultiBoxLoss(21, 0.5, True, 0, False, 3, 0.5,False, Use_cuda,)

# %% [markdown]
# ----

# %% [markdown]
# ## 基本設定

# %%
ssd_net=build_ssd('train', size=300, num_classes=21)
use_pretrained=True
if use_pretrained:
    ssd_net.load_weights('./demo/ssd300_mAP_77.43_v2.pth')
net=ssd_net
# Out:
# Loading weights into state dict...
# Finished!

# %%
'''要不要使用gpu'''
Use_cuda=True

'''tensor type會依照cpu或gpu有所不同'''
if torch.cuda.is_available():
    if Use_cuda: # args.cuda = Use_cuda
        torch.set_default_tensor_type('torch.cuda.FloatTensor')
    if not Use_cuda: # args.cuda = Use_cuda
        print("WARNING: It looks like you have a CUDA device, but aren't " +
              "using CUDA.\nRun with --cuda for optimal training speed.")
        torch.set_default_tensor_type('torch.FloatTensor')
else:
    torch.set_default_tensor_type('torch.FloatTensor')

'''使用GPU時可以開啟DataParallel，但當Input是不定大小時，要關掉'''
if Use_cuda:
    net = torch.nn.DataParallel(ssd_net)
    cudnn.benchmark = True
'''使用GPU時模型要轉成cuda'''
if Use_cuda:
    net = net.cuda()
    
batch_size_=1
optimizer = optim.Adam(net.parameters(),lr=0.00001/batch_size_)

# %% [markdown]
# ---

# %% [markdown]
# ## 訓練

# %% [markdown]
# ## 這裡我們先示範輸入的 image,Label格式，真正在訓練時，準備成一樣格式即可

# %%
'''輸入影像格式，假設batch size 為 4'''
image_in=torch.tensor(torch.rand(4,3,300,300),dtype=torch.float32)
'''Label格式，沒有固定長度，看圖像中有幾個label就有幾個'''
label_0=[[ 0.1804,  0.6076,  0.7701,  0.8485, 0.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 3.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 19.0000],
       [ 0.2950,  0.0000,  0.8238,  0.3641, 6.0000],]
label_1=[[ 0.1804,  0.6076,  0.7701,  0.8485, 13.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 11.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 7.0000],
       [ 0.2950,  0.0000,  0.8238,  0.3641, 5.0000],]
label_2=[[ 0.1804,  0.6076,  0.7701,  0.8485, 0.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 3.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 14.0000],
       [ 0.2950,  0.0000,  0.8238,  0.3641, 6.0000],]
label_3=[[ 0.1804,  0.6076,  0.7701,  0.8485, 0.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 3.0000],
       [ 0.2250,  0.0000,  0.9238,  0.5641, 19.0000],
       [ 0.2950,  0.0000,  0.8238,  0.3641, 6.0000],]
# Out:
# C:\Users\WASN\anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
epochs=300
iteration=1000

# %%
for epoch in range(epochs):
    n=0
    loss_sum=[]
    loc_loss=[]
    conf_loss=[]
    for number__ in range(iteration) :
        '''要用Variable包裝tensor才能送入模型'''
        if Use_cuda:
            image_ = Variable(image_in.cuda())
            y = [Variable(torch.tensor(label_0).cuda(), volatile=True),Variable(torch.tensor(label_1).cuda(), 
                volatile=True),Variable(torch.tensor(label_2).cuda(), volatile=True),Variable(torch.tensor(label_3).cuda(), volatile=True)]      
        else:
            image_ = Variable(image_in)
            y = [Variable(torch.tensor(label_0), volatile=True),Variable(torch.tensor(label_1), 
                volatile=True),Variable(torch.tensor(label_2), volatile=True),Variable(torch.tensor(label_3), volatile=True)]

        '''Forward Pass'''
        out = net(image_)
        '''Regression Loss and Classification Loss'''
        loss_l,loss_c = criterion(out,y )
        loss = loss_l+ loss_c
        '''Backward'''
        loss.backward()

        loc_loss.append(loss_l.data.cpu().numpy())
        conf_loss.append(loss_c.data.cpu().numpy())
        loss_sum.append(loss.data.cpu().numpy())
        '''更新參數'''
        optimizer.step()
        '''清空Gradients'''
        optimizer.zero_grad()
        
        n+=1
        if n%10==0:
            print('BBOX Regression Loss: ', np.mean(loc_loss))
            print('Classification Loss: ', np.mean(conf_loss))
    '''儲存權重'''
    # add weights folder
    torch.save(ssd_net.state_dict(),'weights/Ｗeights.pth')
print('OK')
# Out:
# C:\Users\WASN\anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:10: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\WASN\anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:11: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\WASN\anaconda3\envs\pytorch\lib\site-packages\torch\nn\_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# BBOX Regression Loss:  1.9426420988859951
# Classification Loss:  8.102121423791955
# BBOX Regression Loss:  1.7405735298439307
# Classification Loss:  6.2934001922607425
# BBOX Regression Loss:  1.6230697066695603
# Classification Loss:  5.450192750530479
# BBOX Regression Loss:  1.486442048461349
# Classification Loss:  4.896644973754883
# BBOX Regression Loss:  1.3557017771402997
# Classification Loss:  4.464561790183739
# BBOX Regression Loss:  1.2322943575588274
# Classification Loss:  4.095351720739294
# BBOX Regression Loss:  1.1219182998415025
# Classification Loss:  3.7627524098391265
# BBOX Regression Loss:  1.0217142208858772
# Classification Loss:  3.4559710873497855
# BBOX Regression Loss:  0.9296513298411427
# Classification Loss:  3.1756977371718165
# BBOX Regression Loss:  0.8486495307639792
# Classification Loss:  2.9223706369046805
# BBOX Regression Loss:  0.7789011835249187
# Classification Loss:  2.6941917413011547
# BBOX Regression Loss:  0.7186756059711361
# Classification Loss:  2.490945437955267
# BBOX Regression Loss:  0.6661591310107129
# Classification Loss:  2.311283492091035
# BBOX Regression Loss:  0.6201344741399956
# Classification Loss:  2.1527423495022706
# BBOX Regression Loss:  0.579606196578638
# Classification Loss:  2.0127363908732376
# BBOX Regression Loss:  0.5438244465807521
# Classification Loss:  1.8888678270081676
# BBOX Regression Loss:  0.5120827503827012
# Classification Loss:  1.7789000099520795
# BBOX Regression Loss:  0.4839340675269625
# Classification Loss:  1.6808416883886597
# BBOX Regression Loss:  0.4586029986264529
# Classification Loss:  1.5929251867195782
# BBOX Regression Loss:  0.43575158533674696
# Classification Loss:  1.5136891123321323
# BBOX Regression Loss:  0.4150556616117189
# Classification Loss:  1.441921560999788
# BBOX Regression Loss:  0.39632205360471856
# Classification Loss:  1.3766247413174473
# BBOX Regression Loss:  0.37918706240639355
# Classification Loss:  1.3169736076860226
# BBOX Regression Loss:  0.36343439100712627
# Classification Loss:  1.2622687605979999
# BBOX Regression Loss:  0.3489227631849547
# Classification Loss:  1.211918056964874
# BBOX Regression Loss:  0.33552054186375474
# Classification Loss:  1.1654229920644026
# BBOX Regression Loss:  0.32321359402243305
# Classification Loss:  1.1223607233195312
# BBOX Regression Loss:  0.3117368566154418
# Classification Loss:  1.082367748510901
# BBOX Regression Loss:  0.3010158975519439
# Classification Loss:  1.0451257441844672
# BBOX Regression Loss:  0.2909951500558972
# Classification Loss:  1.0103587672887027
# BBOX Regression Loss:  0.28161556349740124
# Classification Loss:  0.977827976695668
# BBOX Regression Loss:  0.2728203278193918
# Classification Loss:  0.9473245935169634
# BBOX Regression Loss:  0.26463897240904233
# Classification Loss:  0.9186657727500538
# BBOX Regression Loss:  0.2569628604003461
# Classification Loss:  0.8916934401770824
# BBOX Regression Loss:  0.24964977078095432
# Classification Loss:  0.8662611178367857
# BBOX Regression Loss:  0.24272562256569152
# Classification Loss:  0.842238369044453
# BBOX Regression Loss:  0.23617074934416565
# Classification Loss:  0.8195109111888033
# BBOX Regression Loss:  0.22995860048006497
# Classification Loss:  0.797976763404136
# BBOX Regression Loss:  0.22406416717188826
# Classification Loss:  0.7775445023719628
# BBOX Regression Loss:  0.21846408089565725
# Classification Loss:  0.7581317633500807
# BBOX Regression Loss:  0.21313695273662445
# Classification Loss:  0.7396641754630244
# BBOX Regression Loss:  0.2081061874016359
# Classification Loss:  0.7220747393380186
# BBOX Regression Loss:  0.20336300768738277
# Classification Loss:  0.7053055009689955
# BBOX Regression Loss:  0.19876221606003433
# Classification Loss:  0.6892982436852022
# BBOX Regression Loss:  0.1943536972782647
# Classification Loss:  0.6740009728086337
# BBOX Regression Loss:  0.19013205124562058
# Classification Loss:  0.6593675213447515
# BBOX Regression Loss:  0.1860882254094755
# Classification Loss:  0.6453555257326039
# BBOX Regression Loss:  0.1822123335712761
# Classification Loss:  0.6319262352162671
# BBOX Regression Loss:  0.17849434889901925
# Classification Loss:  0.6190441097261682
# BBOX Regression Loss:  0.1749249636664193
# Classification Loss:  0.6066764024187016
# BBOX Regression Loss:  0.17149549356557578
# Classification Loss:  0.5947929429332673
# BBOX Regression Loss:  0.16819788451507015
# Classification Loss:  0.5833658689701999
# BBOX Regression Loss:  0.16502472346020206
# Classification Loss:  0.5723694132642259
# BBOX Regression Loss:  0.16201852650202928
# Classification Loss:  0.5617800781510984
# BBOX Regression Loss:  0.1591197308786731
# Classification Loss:  0.5515766596473026
# BBOX Regression Loss:  0.15629093225454208
# Classification Loss:  0.5417377228065143
# BBOX Regression Loss:  0.1535541606166907
# Classification Loss:  0.5322435393822976
# BBOX Regression Loss:  0.15090868351172232
# Classification Loss:  0.5230762220662216
# BBOX Regression Loss:  0.14835175021564848
# Classification Loss:  0.5142191419269181
# BBOX Regression Loss:  0.14587966398891836
# Classification Loss:  0.505656845179605
# BBOX Regression Loss:  0.1434884647996695
# Classification Loss:  0.4973748631309435
# BBOX Regression Loss:  0.1411743365475889
# Classification Loss:  0.48935967868231817
# BBOX Regression Loss:  0.1389348948286651
# Classification Loss:  0.4815986177838598
# BBOX Regression Loss:  0.13685984450328556
# Classification Loss:  0.474080393884193
# BBOX Regression Loss:  0.1347814532964652
# Classification Loss:  0.4667947555810977
# BBOX Regression Loss:  0.13274916912253693
# Classification Loss:  0.4597298343106685
# BBOX Regression Loss:  0.13077135495439937
# Classification Loss:  0.45287546434739856
# BBOX Regression Loss:  0.12884954497234488
# Classification Loss:  0.44622232888648716
# BBOX Regression Loss:  0.1269827235606124
# Classification Loss:  0.4397616486810448
# BBOX Regression Loss:  0.1251689667970779
# Classification Loss:  0.4334852097211061
# BBOX Regression Loss:  0.12340619888933026
# Classification Loss:  0.4273852630462507
# BBOX Regression Loss:  0.12169235255932867
# Classification Loss:  0.4214544884032673
# BBOX Regression Loss:  0.12002598259598296
# Classification Loss:  0.41568595780629547
# BBOX Regression Loss:  0.11845031230839374
# Classification Loss:  0.4100735315033146
# BBOX Regression Loss:  0.11688963325360122
# Classification Loss:  0.4046110006791574
# BBOX Regression Loss:  0.11535808451447659
# Classification Loss:  0.39929222156081284
# BBOX Regression Loss:  0.11386210482781998
# Classification Loss:  0.39411140578248405
# BBOX Regression Loss:  0.11240338608805729
# Classification Loss:  0.3890632079933671
# BBOX Regression Loss:  0.11098095777651215
# Classification Loss:  0.3841426025854273
# BBOX Regression Loss:  0.10959388607377654
# Classification Loss:  0.37934481152229843
# BBOX Regression Loss:  0.10824098250861806
# Classification Loss:  0.3746653022589508
# BBOX Regression Loss:  0.10692104335018475
# Classification Loss:  0.3700997645238982
# BBOX Regression Loss:  0.10563289498951274
# Classification Loss:  0.36564409782289664
# BBOX Regression Loss:  0.10437541067503957
# Classification Loss:  0.361294387357155
# BBOX Regression Loss:  0.10314751000469785
# Classification Loss:  0.3570469006525924
# BBOX Regression Loss:  0.10194816232953653
# Classification Loss:  0.3528980834693563
# BBOX Regression Loss:  0.10077638342596475
# Classification Loss:  0.3488445382617595
# BBOX Regression Loss:  0.09963123355935792
# Classification Loss:  0.3448830247176215
# BBOX Regression Loss:  0.09851181545327663
# Classification Loss:  0.34101044116196805
# BBOX Regression Loss:  0.09741727144498988
# Classification Loss:  0.3372238265977474
# BBOX Regression Loss:  0.09634693096313399
# Classification Loss:  0.33352035529544594
# BBOX Regression Loss:  0.09538127406220963
# Classification Loss:  0.32989766400505377
# BBOX Regression Loss:  0.09439162275075921
# Classification Loss:  0.3263541690812363
# BBOX Regression Loss:  0.09339707759616665
# Classification Loss:  0.3228862275421572
# BBOX Regression Loss:  0.09241722085449094
# Classification Loss:  0.3194910973972744
# BBOX Regression Loss:  0.09145568423053915
# Classification Loss:  0.3161664909832638
# BBOX Regression Loss:  0.09051332215415243
# Classification Loss:  0.3129102314051073
# BBOX Regression Loss:  0.08958993138115993
# Classification Loss:  0.30972023615310873
# BBOX Regression Loss:  0.08868508959471348
# Classification Loss:  0.3065945189453178
# BBOX Regression Loss:  0.08779830174336907
# Classification Loss:  0.3035311717854605
# BBOX Regression Loss:  4.396874013494839e-06
# Classification Loss:  0.0002466713940655743
# BBOX Regression Loss:  3.911734920283951e-06
# Classification Loss:  0.00024078510425708916
# BBOX Regression Loss:  3.5567192955770433e-06
# Classification Loss:  0.00023547043035059798
# BBOX Regression Loss:  3.2892471305482716e-06
# Classification Loss:  0.00023040528650637026
# BBOX Regression Loss:  3.0771924368174813e-06
# Classification Loss:  0.0002255741755167643
# BBOX Regression Loss:  2.9049169218827347e-06
# Classification Loss:  0.0002209514747431249
# BBOX Regression Loss:  3.369111750520046e-06
# Classification Loss:  0.00021650412726023838
# BBOX Regression Loss:  0.0004139628354938328
# Classification Loss:  0.0002137739349294592
# BBOX Regression Loss:  0.0005854126321646019
# Classification Loss:  0.00021541314851109385
# BBOX Regression Loss:  0.0005982526925395683
# Classification Loss:  0.00021731217702229816
# BBOX Regression Loss:  0.0005722674269025153
# Classification Loss:  0.00021863063979229142
# BBOX Regression Loss:  0.0005331799089056145
# Classification Loss:  0.00021905207339628242
# BBOX Regression Loss:  0.0004948516554650062
# Classification Loss:  0.00021870509851352438
# BBOX Regression Loss:  0.0004606119215476269
# Classification Loss:  0.00021778130657458433
# BBOX Regression Loss:  0.00043033792373557554
# Classification Loss:  0.00021637286668942297
# BBOX Regression Loss:  0.0004036650467654639
# Classification Loss:  0.00021460288100772434
# BBOX Regression Loss:  0.0003800461952817907
# Classification Loss:  0.000212583147102971
# BBOX Regression Loss:  0.00035902561513343433
# Classification Loss:  0.00021038433161292056
# BBOX Regression Loss:  0.0003402055007975232
# Classification Loss:  0.00020806719685158534
# BBOX Regression Loss:  0.0003232618724305886
# Classification Loss:  0.00020568494443540218
# BBOX Regression Loss:  0.0003079712210277539
# Classification Loss:  0.00020325713687472876
# BBOX Regression Loss:  0.0003245018660927966
# Classification Loss:  0.00020083618485164964
# BBOX Regression Loss:  0.0006548456760690124
# Classification Loss:  0.00020054365701721485
# BBOX Regression Loss:  0.0006910131098765653
# Classification Loss:  0.0002029156611289507
# BBOX Regression Loss:  0.000683294997861527
# Classification Loss:  0.00020512810459843387
# BBOX Regression Loss:  0.0006633944326865646
# Classification Loss:  0.00020688412196276192
# BBOX Regression Loss:  0.0006412579123474235
# Classification Loss:  0.00020802119141252935
# BBOX Regression Loss:  0.0006193538775348061
# Classification Loss:  0.00020860064597356883
# BBOX Regression Loss:  0.0005983975898610086
# Classification Loss:  0.0002087259353501282
# BBOX Regression Loss:  0.000578645570338851
# Classification Loss:  0.0002084811528523763
# BBOX Regression Loss:  0.0005600909255877736
# Classification Loss:  0.00020793358769752933
# BBOX Regression Loss:  0.0005426626581378581
# Classification Loss:  0.00020715674316441573
# BBOX Regression Loss:  0.0005262743939712583
# Classification Loss:  0.00020619527793224945
# BBOX Regression Loss:  0.0005108423300927532
# Classification Loss:  0.00020506327448327558
# BBOX Regression Loss:  0.0004962877501730829
# Classification Loss:  0.00020379066467285156
# BBOX Regression Loss:  0.0004825385660536426
# Classification Loss:  0.00020240292627625014
# BBOX Regression Loss:  0.00046952976301073906
# Classification Loss:  0.00020092278271466042
# BBOX Regression Loss:  0.0004572035752042718
# Classification Loss:  0.0001993643145347432
# BBOX Regression Loss:  0.000445507656003198
# Classification Loss:  0.00019775315454089966
# BBOX Regression Loss:  0.00043439508774655326
# Classification Loss:  0.00019610638971681945
# BBOX Regression Loss:  0.0004238235031729479
# Classification Loss:  0.00019442742217631629
# BBOX Regression Loss:  0.000413754290371635
# Classification Loss:  0.0001927290643964495
# BBOX Regression Loss:  0.00040415233501167385
# Classification Loss:  0.00019101846023020715
# BBOX Regression Loss:  0.00039498589298725135
# Classification Loss:  0.00018930160236679746
# BBOX Regression Loss:  0.00038622616572150936
# Classification Loss:  0.0001875821062566812
# BBOX Regression Loss:  0.00037784765611183164
# Classification Loss:  0.00018586680509042046
# BBOX Regression Loss:  0.0003700597684804878
# Classification Loss:  0.00018415948929422198
# BBOX Regression Loss:  0.00040367458064669514
# Classification Loss:  0.0001825747114640695
# BBOX Regression Loss:  0.0004132418404116609
# Classification Loss:  0.0001813264480613887
# BBOX Regression Loss:  0.0004115409597973296
# Classification Loss:  0.00018024008362381544
# BBOX Regression Loss:  0.0004053978831840153
# Classification Loss:  0.00017915615242464263
# BBOX Regression Loss:  0.00039832444545234393
# Classification Loss:  0.0001780349135059237
# BBOX Regression Loss:  0.00039110490878531656
# Classification Loss:  0.0001768769624764731
# BBOX Regression Loss:  0.0003839628190687342
# Classification Loss:  0.00017568592508470407
# BBOX Regression Loss:  0.0003770298215523182
# Classification Loss:  0.00017446887212168888
# BBOX Regression Loss:  0.00037032048147194526
# Classification Loss:  0.00017322850605798145
# BBOX Regression Loss:  0.000363868354872987
# Classification Loss:  0.00017196895086277298
# BBOX Regression Loss:  0.00036532866635443755
# Classification Loss:  0.00017070579955099795
# BBOX Regression Loss:  0.00043482062325692517
# Classification Loss:  0.00016971716548538926
# BBOX Regression Loss:  0.0004430736041306066
# Classification Loss:  0.0001690991278047915
# BBOX Regression Loss:  0.00044066273196617417
# Classification Loss:  0.00016859266782574172
# BBOX Regression Loss:  0.0004355256036622346
# Classification Loss:  0.00016806779369231195
# BBOX Regression Loss:  0.0004292543059149966
# Classification Loss:  0.00016748849116375277
# BBOX Regression Loss:  0.0004228058364253263
# Classification Loss:  0.00016683878170119395
# BBOX Regression Loss:  0.0004164104694339706
# Classification Loss:  0.00016612450961034185
# BBOX Regression Loss:  0.000410146392617878
# Classification Loss:  0.00016535535270785108
# BBOX Regression Loss:  0.00040404719207028415
# Classification Loss:  0.00016453496786426482
# BBOX Regression Loss:  0.000398119258101923
# Classification Loss:  0.0001636773802356263
# BBOX Regression Loss:  0.00039236007938330523
# Classification Loss:  0.00016278785463948436
# BBOX Regression Loss:  0.00038676385072441977
# Classification Loss:  0.0001618707495391684
# BBOX Regression Loss:  0.0003813244689418939
# Classification Loss:  0.0001609361849542577
# BBOX Regression Loss:  0.0003760356752619886
# Classification Loss:  0.000159982263796614
# BBOX Regression Loss:  0.0003708913677144066
# Classification Loss:  0.00015901794656166142
# BBOX Regression Loss:  0.0003658857424249015
# Classification Loss:  0.00015804341605475715
# BBOX Regression Loss:  0.0003610133194634716
# Classification Loss:  0.00015706087041784215
# BBOX Regression Loss:  0.0003562691334157395
# Classification Loss:  0.00015607407683285125
# BBOX Regression Loss:  0.00035167761305894665
# Classification Loss:  0.0001550841755795903
# BBOX Regression Loss:  0.00035319038788518857
# Classification Loss:  0.000154099471209056
# BBOX Regression Loss:  0.00038572555596188505
# Classification Loss:  0.00015331811319200075
# BBOX Regression Loss:  0.0003885418291741661
# Classification Loss:  0.00015269228705653437
# BBOX Regression Loss:  0.0003862153026374446
# Classification Loss:  0.00015213294393350176
# BBOX Regression Loss:  0.0003822883342551847
# Classification Loss:  0.00015156424142480864
# BBOX Regression Loss:  0.00037796925949677636
# Classification Loss:  0.00015096512291911244
# BBOX Regression Loss:  0.0003735785800793323
# Classification Loss:  0.00015033376279962126
# BBOX Regression Loss:  0.00036922851880605696
# Classification Loss:  0.00014967378188322314
# BBOX Regression Loss:  0.0003649542199366537
# Classification Loss:  0.00014898746204622648
# BBOX Regression Loss:  0.0003607690084131976
# Classification Loss:  0.00014828065447525148
# BBOX Regression Loss:  0.00035667561847702034
# Classification Loss:  0.00014755493061309713
# BBOX Regression Loss:  0.00035267288505843187
# Classification Loss:  0.00014681374585186994
# BBOX Regression Loss:  0.000348759614672144
# Classification Loss:  0.00014606065710876212
# BBOX Regression Loss:  0.0003450117854632014
# Classification Loss:  0.00014529835658680872
# BBOX Regression Loss:  0.00036197833490034633
# Classification Loss:  0.0001445423673700403
# BBOX Regression Loss:  0.00039239829272987286
# Classification Loss:  0.0001440504925605169
# BBOX Regression Loss:  0.00040047971355976203
# Classification Loss:  0.00014382922057564376
# BBOX Regression Loss:  0.00040015082851550506
# Classification Loss:  0.00014363589110197842
# BBOX Regression Loss:  0.00039739006125192184
# Classification Loss:  0.00014343384975268515
# BBOX Regression Loss:  0.00039381906463352526
# Classification Loss:  0.00014319342481766828
# BBOX Regression Loss:  0.000389985457743851
# Classification Loss:  0.0001428981306691649
# BBOX Regression Loss:  0.00038612049203357436
# Classification Loss:  0.0001425472663397027
# BBOX Regression Loss:  0.00038229166449673356
# Classification Loss:  0.0001421483004534686
# BBOX Regression Loss:  1.5887882842367548e-06
# Classification Loss:  9.781431268762659e-05
# BBOX Regression Loss:  1.2776543203303678e-06
# Classification Loss:  9.570033461959273e-05
# BBOX Regression Loss:  1.0880195268215668e-06
# Classification Loss:  9.37152791906286e-05
# BBOX Regression Loss:  9.623168420215803e-07
# Classification Loss:  9.185318593625668e-05
# BBOX Regression Loss:  8.738534914435283e-07
# Classification Loss:  9.011250955087168e-05
# BBOX Regression Loss:  8.081872193194871e-07
# Classification Loss:  8.84449040448224e-05
# BBOX Regression Loss:  7.557756708549622e-07
# Classification Loss:  8.686307876829116e-05
# BBOX Regression Loss:  7.117510137875259e-07
# Classification Loss:  8.536566186834265e-05
# BBOX Regression Loss:  6.746387773518232e-07
# Classification Loss:  8.395758185367034e-05
# BBOX Regression Loss:  7.597698694789195e-07
# Classification Loss:  8.261097802056206e-05
# BBOX Regression Loss:  0.00012242591696281203
# Classification Loss:  8.140774286957301e-05
# BBOX Regression Loss:  0.0005886886278431906
# Classification Loss:  8.275324915662224e-05
# BBOX Regression Loss:  0.0006257301908432247
# Classification Loss:  8.623708686937294e-05
# BBOX Regression Loss:  0.0006070886263899859
# Classification Loss:  8.963220333926892e-05
# BBOX Regression Loss:  0.0005752692666714279
# Classification Loss:  9.239155569194277e-05
# BBOX Regression Loss:  0.0005422088204770464
# Classification Loss:  9.442451927396985e-05
# BBOX Regression Loss:  0.0005113687228217982
# Classification Loss:  9.582577707461022e-05
# BBOX Regression Loss:  0.00048338478885882907
# Classification Loss:  9.671292677828312e-05
# BBOX Regression Loss:  0.000458135462744763
# Classification Loss:  9.717769325360451e-05
# BBOX Regression Loss:  0.0004353307595495911
# Classification Loss:  9.730197765209056e-05
# BBOX Regression Loss:  0.0004146652020279769
# Classification Loss:  9.717478743726404e-05
# BBOX Regression Loss:  0.00039586352840671946
# Classification Loss:  9.685212915593928e-05
# BBOX Regression Loss:  0.0003786890310456271
# Classification Loss:  9.638345567884461e-05
# BBOX Regression Loss:  0.0003629410737448218
# Classification Loss:  9.58067031554234e-05
# BBOX Regression Loss:  0.00034845003158557957
# Classification Loss:  9.515158335367839e-05
# BBOX Regression Loss:  0.0003350836429954117
# Classification Loss:  9.443043303965165e-05
# BBOX Regression Loss:  0.0003271527958538044
# Classification Loss:  9.367416915579587e-05
# BBOX Regression Loss:  0.00044288320005574544
# Classification Loss:  9.336424252343556e-05
# BBOX Regression Loss:  0.00045920374834811393
# Classification Loss:  9.366174919547401e-05
# BBOX Regression Loss:  0.0004546005839420329
# Classification Loss:  9.418705363332488e-05
# BBOX Regression Loss:  0.00044295749421388407
# Classification Loss:  9.461665523807066e-05
# BBOX Regression Loss:  0.0004301745615070677
# Classification Loss:  9.48840821230853e-05
# BBOX Regression Loss:  0.00041751205525258114
# Classification Loss:  9.500073262738057e-05
# BBOX Regression Loss:  0.00040538289188615025
# Classification Loss:  9.4962042141584e-05
# BBOX Regression Loss:  0.00039386681916348323
# Classification Loss:  9.478922243471498e-05
# BBOX Regression Loss:  0.000382959017225242
# Classification Loss:  9.45099096729922e-05
# BBOX Regression Loss:  0.0003726295242877377
# Classification Loss:  9.41431438839352e-05
# BBOX Regression Loss:  0.00036283940369341355
# Classification Loss:  9.370677420037995e-05
# BBOX Regression Loss:  0.00035354901143547365
# Classification Loss:  9.321804173425163e-05
# BBOX Regression Loss:  0.0003447215750066722
# Classification Loss:  9.268559791423657e-05
# BBOX Regression Loss:  0.0003363237818705947
# Classification Loss:  9.21197053862781e-05
# BBOX Regression Loss:  0.00032832525649430385
# Classification Loss:  9.152439325995334e-05
# BBOX Regression Loss:  0.0003206981888558828
# Classification Loss:  9.090409619760965e-05
# BBOX Regression Loss:  0.0003134174684877697
# Classification Loss:  9.026794321207888e-05
# BBOX Regression Loss:  0.0003064784079943809
# Classification Loss:  8.961877705138406e-05
# BBOX Regression Loss:  0.00030784924503403886
# Classification Loss:  8.896044103035796e-05
# BBOX Regression Loss:  0.00038666685756979976
# Classification Loss:  8.855206089004745e-05
# BBOX Regression Loss:  0.0003951851315701524
# Classification Loss:  8.855833683484867e-05
# BBOX Regression Loss:  0.00039255300656831167
# Classification Loss:  8.86826648553573e-05
# BBOX Regression Loss:  0.0003867592869849398
# Classification Loss:  8.87789902863679e-05
# BBOX Regression Loss:  0.0003799811158882163
# Classification Loss:  8.880868716437313e-05
# BBOX Regression Loss:  0.00037296499312814563
# Classification Loss:  8.876515589548312e-05
# BBOX Regression Loss:  0.0003660348789838514
# Classification Loss:  8.865955574040977e-05
# BBOX Regression Loss:  0.0003593009027601626
# Classification Loss:  8.848184420738692e-05
# BBOX Regression Loss:  0.00035279090191258055
# Classification Loss:  8.824019319682008e-05
# BBOX Regression Loss:  0.0003465046599326679
# Classification Loss:  8.794777292423146e-05
# BBOX Regression Loss:  0.000340435057390322
# Classification Loss:  8.761390143202992e-05
# BBOX Regression Loss:  0.0003345731793616576
# Classification Loss:  8.724632543317811e-05
# BBOX Regression Loss:  0.00032890905573705484
# Classification Loss:  8.685129360814404e-05
# BBOX Regression Loss:  0.00032343307947867064
# Classification Loss:  8.643072328449767e-05
# BBOX Regression Loss:  0.0003181362388662219
# Classification Loss:  8.599147263916608e-05
# BBOX Regression Loss:  0.0003130099650403507
# Classification Loss:  8.55362258646793e-05
# BBOX Regression Loss:  0.000308046143840359
# Classification Loss:  8.506591287800173e-05
# BBOX Regression Loss:  0.0003032371475662196
# Classification Loss:  8.458470304807027e-05
# BBOX Regression Loss:  0.00029857608221297996
# Classification Loss:  8.409265099767266e-05
# BBOX Regression Loss:  0.00029407188793631494
# Classification Loss:  8.359379506137904e-05
# BBOX Regression Loss:  0.0002940769491996821
# Classification Loss:  8.30905749825498e-05
# BBOX Regression Loss:  0.00032465747913294453
# Classification Loss:  8.272697463274522e-05
# BBOX Regression Loss:  0.0003283715089650647
# Classification Loss:  8.252419519347655e-05
# BBOX Regression Loss:  0.0003264889867579682
# Classification Loss:  8.237543560209729e-05
# BBOX Regression Loss:  0.0003228252372414458
# Classification Loss:  8.221602900051858e-05
# BBOX Regression Loss:  0.00031868785411308446
# Classification Loss:  8.202511587260683e-05
# BBOX Regression Loss:  0.00031445365608342475
# Classification Loss:  8.180015647187564e-05
# BBOX Regression Loss:  0.00031025475568801703
# Classification Loss:  8.154280550845033e-05
# BBOX Regression Loss:  0.00030613981807230486
# Classification Loss:  8.125999827443817e-05
# BBOX Regression Loss:  0.0003021214369714577
# Classification Loss:  8.095379693698697e-05
# BBOX Regression Loss:  0.000298203612038838
# Classification Loss:  8.062917260724573e-05
# BBOX Regression Loss:  0.00029438489332790304
# Classification Loss:  8.028975465924879e-05
# BBOX Regression Loss:  0.000290662514339548
# Classification Loss:  7.99364290268724e-05
# BBOX Regression Loss:  0.0002870785215470017
# Classification Loss:  7.957103075804532e-05
# BBOX Regression Loss:  0.0002941039429012733
# Classification Loss:  7.92048104996544e-05
# BBOX Regression Loss:  0.00030889642867358027
# Classification Loss:  7.892233246387181e-05
# BBOX Regression Loss:  0.00030925121436754067
# Classification Loss:  7.870998408101808e-05
# BBOX Regression Loss:  0.00030680411121233837
# Classification Loss:  7.851194242110748e-05
# BBOX Regression Loss:  0.0003036261381351488
# Classification Loss:  7.830431778186807e-05
# BBOX Regression Loss:  0.00030025580991434076
# Classification Loss:  7.807547218526467e-05
# BBOX Regression Loss:  0.0002968627035137524
# Classification Loss:  7.782642158258209e-05
# BBOX Regression Loss:  0.00029351340501028987
# Classification Loss:  7.756099556431626e-05
# BBOX Regression Loss:  0.00029022614171025034
# Classification Loss:  7.728201818128849e-05
# BBOX Regression Loss:  0.0002870067205258275
# Classification Loss:  7.698860678653168e-05
# BBOX Regression Loss:  0.00028385653363803575
# Classification Loss:  7.668330410315731e-05
# BBOX Regression Loss:  0.0002807742363637004
# Classification Loss:  7.636787042909582e-05
# BBOX Regression Loss:  0.0002777735841734412
# Classification Loss:  7.604294590435386e-05
# BBOX Regression Loss:  0.0002789949876203241
# Classification Loss:  7.571317343565309e-05
# BBOX Regression Loss:  0.00031940319135587006
# Classification Loss:  7.550445913571363e-05
# BBOX Regression Loss:  0.0003282802687291528
# Classification Loss:  7.564531248292805e-05
# BBOX Regression Loss:  0.0003290597456753618
# Classification Loss:  7.578012095739388e-05
# BBOX Regression Loss:  0.00032713623866672723
# Classification Loss:  7.591663845001705e-05
# BBOX Regression Loss:  0.0003243632157836814
# Classification Loss:  7.601795774517637e-05
# BBOX Regression Loss:  0.000321312570846422
# Classification Loss:  7.607071487991898e-05
# BBOX Regression Loss:  7.593103132590099e-06
# Classification Loss:  7.694209063494647e-05
# BBOX Regression Loss:  5.343695226690249e-06
# Classification Loss:  7.49702806825991e-05
# BBOX Regression Loss:  4.049600349030641e-06
# Classification Loss:  7.312857074502073e-05
# BBOX Regression Loss:  3.2449860285581693e-06
# Classification Loss:  7.15090168846978e-05
# BBOX Regression Loss:  2.7160175287227266e-06
# Classification Loss:  6.982202883119936e-05
# BBOX Regression Loss:  2.342660898221642e-06
# Classification Loss:  6.81563659950539e-05
# BBOX Regression Loss:  2.0665679238889078e-06
# Classification Loss:  6.657845128780948e-05
# BBOX Regression Loss:  1.8533957468544368e-06
# Classification Loss:  6.510791955170808e-05
# BBOX Regression Loss:  1.6843713720422765e-06
# Classification Loss:  6.373615421876004e-05
# BBOX Regression Loss:  1.5503733869048085e-06
# Classification Loss:  6.243016984727649e-05
# BBOX Regression Loss:  2.088433545398736e-06
# Classification Loss:  6.120702634355434e-05
# BBOX Regression Loss:  0.0001973021275127259
# Classification Loss:  6.018464947924202e-05
# BBOX Regression Loss:  0.000325443537786329
# Classification Loss:  6.052068835310106e-05
# BBOX Regression Loss:  0.0003362668334288866
# Classification Loss:  6.153110473875015e-05
# BBOX Regression Loss:  0.00032484240310926303
# Classification Loss:  6.253130641984351e-05
# BBOX Regression Loss:  0.0003082611290850494
# Classification Loss:  6.325151081438417e-05
# BBOX Regression Loss:  0.000291221706867956
# Classification Loss:  6.370305495584193e-05
# BBOX Regression Loss:  0.00027543638824393494
# Classification Loss:  6.39164889300311e-05
# BBOX Regression Loss:  0.00026109838820179214
# Classification Loss:  6.393614800585176e-05
# BBOX Regression Loss:  0.00024811291169583085
# Classification Loss:  6.382783253987631e-05
# BBOX Regression Loss:  0.00023633344149068096
# Classification Loss:  6.362193475955377e-05
# BBOX Regression Loss:  0.00022561397234294232
# Classification Loss:  6.329419235589127e-05
# BBOX Regression Loss:  0.0002158330325556927
# Classification Loss:  6.287201591159987e-05
# BBOX Regression Loss:  0.0002094858687439542
# Classification Loss:  6.238902792518522e-05
# BBOX Regression Loss:  0.0003384258740852938
# Classification Loss:  6.223021613226996e-05
# BBOX Regression Loss:  0.0003787274044526693
# Classification Loss:  6.286805851167423e-05
# BBOX Regression Loss:  0.0003792468832695476
# Classification Loss:  6.37398498702605e-05
# BBOX Regression Loss:  0.0003710693308602742
# Classification Loss:  6.451092699848155e-05
# BBOX Regression Loss:  0.000360230157683098
# Classification Loss:  6.511564607973451e-05
# BBOX Regression Loss:  0.0003488682917743715
# Classification Loss:  6.553894207801348e-05
# BBOX Regression Loss:  0.0003378583091244387
# Classification Loss:  6.581321269665425e-05
# BBOX Regression Loss:  0.0003274038044237512
# Classification Loss:  6.59538088021455e-05
# BBOX Regression Loss:  0.00031752941265798557
# Classification Loss:  6.598093694307989e-05
# BBOX Regression Loss:  0.00030821432692926677
# Classification Loss:  6.590544008741192e-05
# BBOX Regression Loss:  0.0002994251328192828
# Classification Loss:  6.575006656545811e-05
# BBOX Regression Loss:  0.00029112085706760863
# Classification Loss:  6.553668053552448e-05
# BBOX Regression Loss:  0.0002832637391936903
# Classification Loss:  6.528289707096012e-05
# BBOX Regression Loss:  0.00027581913974186745
# Classification Loss:  6.498765294779579e-05
# BBOX Regression Loss:  0.00026875554284806026
# Classification Loss:  6.464263539255402e-05
# BBOX Regression Loss:  0.0002620443897719977
# Classification Loss:  6.425190854955603e-05
# BBOX Regression Loss:  0.00025565986268221097
# Classification Loss:  6.383005950293675e-05
# BBOX Regression Loss:  0.000249578805408369
# Classification Loss:  6.338622834947375e-05
# BBOX Regression Loss:  0.00024378015109540463
# Classification Loss:  6.292765762762814e-05
# BBOX Regression Loss:  0.00023824481047850812
# Classification Loss:  6.245541251468338e-05
# BBOX Regression Loss:  0.00023295519859569254
# Classification Loss:  6.197587943371432e-05
# BBOX Regression Loss:  0.00022789532495442506
# Classification Loss:  6.149064707487294e-05
# BBOX Regression Loss:  0.00022306854379166191
# Classification Loss:  6.099677254967656e-05
# BBOX Regression Loss:  0.00022977547712750974
# Classification Loss:  6.051164718321812e-05
# BBOX Regression Loss:  0.0002805455772506674
# Classification Loss:  6.0268882901400034e-05
# BBOX Regression Loss:  0.0002868291415812834
# Classification Loss:  6.027793884277344e-05
# BBOX Regression Loss:  0.000284979385031701
# Classification Loss:  6.034176853487435e-05
# BBOX Regression Loss:  0.00028083643751182166
# Classification Loss:  6.0386399597863534e-05
# BBOX Regression Loss:  0.0002760058988063947
# Classification Loss:  6.0374098670474306e-05
# BBOX Regression Loss:  0.00027107598972667216
# Classification Loss:  6.0306115405549715e-05
# BBOX Regression Loss:  0.00026621491811010397
# Classification Loss:  6.0195312756881966e-05
# BBOX Regression Loss:  0.0002614882574072581
# Classification Loss:  6.005197921127239e-05
# BBOX Regression Loss:  0.0002569139916925347
# Classification Loss:  5.9882273063634875e-05
# BBOX Regression Loss:  0.00025249208217390667
# Classification Loss:  5.968219932468459e-05
# BBOX Regression Loss:  0.0002482188596034525
# Classification Loss:  5.9452628610422985e-05
# BBOX Regression Loss:  0.00024412675231562592
# Classification Loss:  5.919122401578927e-05
# BBOX Regression Loss:  0.00024633062701559153
# Classification Loss:  5.892017934274585e-05
# BBOX Regression Loss:  0.0002552048359442998
# Classification Loss:  5.8710389951936076e-05
# BBOX Regression Loss:  0.0002537481111677018
# Classification Loss:  5.8543647057445234e-05
# BBOX Regression Loss:  0.0002507545669952075
# Classification Loss:  5.837840338548024e-05
# BBOX Regression Loss:  0.00024718342951117174
# Classification Loss:  5.820112690287098e-05
# BBOX Regression Loss:  0.00024355656618115407
# Classification Loss:  5.80028251365379e-05
# BBOX Regression Loss:  0.00023996284866780091
# Classification Loss:  5.777985302369986e-05
# BBOX Regression Loss:  0.00023645403206271363
# Classification Loss:  5.7533260004712604e-05
# BBOX Regression Loss:  0.00023315279775178798
# Classification Loss:  5.72704846540319e-05
# BBOX Regression Loss:  0.0002564334312339953
# Classification Loss:  5.7018333011203345e-05
# BBOX Regression Loss:  0.0002967313805304921
# Classification Loss:  5.718651822786127e-05
# BBOX Regression Loss:  0.00030989339822129225
# Classification Loss:  5.7574272646334927e-05
# BBOX Regression Loss:  0.0003121888379384845
# Classification Loss:  5.799802289524398e-05
# BBOX Regression Loss:  0.0003101994137156085
# Classification Loss:  5.839072667561972e-05
# BBOX Regression Loss:  0.00030689739135180577
# Classification Loss:  5.870220984941647e-05
# BBOX Regression Loss:  0.0003031581854204375
# Classification Loss:  5.8941058015730414e-05
# BBOX Regression Loss:  0.00029933513250529197
# Classification Loss:  5.9113461217838974e-05
# BBOX Regression Loss:  0.0002955447631338912
# Classification Loss:  5.922708076629205e-05
# BBOX Regression Loss:  0.00029182587706158574
# Classification Loss:  5.928984953660782e-05
# BBOX Regression Loss:  0.00028819115187759425
# Classification Loss:  5.9309800465901697e-05
# BBOX Regression Loss:  0.00028464233800061815
# Classification Loss:  5.9293305214322426e-05
# BBOX Regression Loss:  0.00028117826217996067
# Classification Loss:  5.92430217263929e-05
# BBOX Regression Loss:  0.00027779656633513007
# Classification Loss:  5.916273524749497e-05
# BBOX Regression Loss:  0.0002744946980128171
# Classification Loss:  5.905359089900157e-05
# BBOX Regression Loss:  0.00027127005842368245
# Classification Loss:  5.892338056709772e-05
# BBOX Regression Loss:  0.0002681199671262877
# Classification Loss:  5.877584758038976e-05
# BBOX Regression Loss:  0.00026504186896879377
# Classification Loss:  5.8615872483397616e-05
# BBOX Regression Loss:  0.0002620339570033197
# Classification Loss:  5.844435105821501e-05
# BBOX Regression Loss:  0.0002592288986412409
# Classification Loss:  5.825983699142959e-05
# BBOX Regression Loss:  0.00028839227939358726
# Classification Loss:  5.8093237778777456e-05
# BBOX Regression Loss:  0.00030114664046532717
# Classification Loss:  5.8105586746333825e-05
# BBOX Regression Loss:  0.00030339086909007514
# Classification Loss:  5.823058014714584e-05
# BBOX Regression Loss:  0.00030183971125387685
# Classification Loss:  5.83727869651366e-05
# BBOX Regression Loss:  0.0002992725226420896
# Classification Loss:  5.8482236238424e-05
# BBOX Regression Loss:  0.00029633995414613727
# Classification Loss:  5.8551383064969e-05
# BBOX Regression Loss:  0.0002933409172763636
# Classification Loss:  5.8583096589571165e-05
# BBOX Regression Loss:  0.0002903507427079759
# Classification Loss:  5.85799728836345e-05
# BBOX Regression Loss:  0.00028740256661233867
# Classification Loss:  5.8548052204619373e-05
# BBOX Regression Loss:  0.000284507133325717
# Classification Loss:  5.848793960268739e-05
# BBOX Regression Loss:  0.00028166694711126184
# Classification Loss:  5.840648545159234e-05
# BBOX Regression Loss:  3.6863026522311244e-07
# Classification Loss:  4.8100506817853016e-05
# BBOX Regression Loss:  3.3841101362163e-07
# Classification Loss:  4.70192344100387e-05
# BBOX Regression Loss:  3.152045062534729e-07
# Classification Loss:  4.605982038709851e-05
# BBOX Regression Loss:  2.970483268216884e-07
# Classification Loss:  4.5147869322035046e-05
# BBOX Regression Loss:  2.844417405059277e-07
# Classification Loss:  4.430241054958767e-05
# BBOX Regression Loss:  5.911234890767064e-07
# Classification Loss:  4.3556425306532106e-05
# BBOX Regression Loss:  0.0001362359387070365
# Classification Loss:  4.302698468405103e-05
# BBOX Regression Loss:  0.0006815485293467797
# Classification Loss:  4.622141520182292e-05
# BBOX Regression Loss:  0.000728420514574263
# Classification Loss:  5.1871150609397104e-05
# BBOX Regression Loss:  0.0006929730685558548
# Classification Loss:  5.6690816526059766e-05
# BBOX Regression Loss:  0.0006421750881702604
# Classification Loss:  6.0082284689752334e-05
# BBOX Regression Loss:  0.0005927640079280369
# Classification Loss:  6.236146997522425e-05
# BBOX Regression Loss:  0.0005485182509916541
# Classification Loss:  6.384686527089176e-05
# BBOX Regression Loss:  0.0005098646644464007
# Classification Loss:  6.471847100232644e-05
# BBOX Regression Loss:  0.00047610244630690165
# Classification Loss:  6.512135635187597e-05
# BBOX Regression Loss:  0.0004464540026873465
# Classification Loss:  6.52117861641778e-05
# BBOX Regression Loss:  0.00042025792783646635
# Classification Loss:  6.506048256535415e-05
# BBOX Regression Loss:  0.00039695419781293355
# Classification Loss:  6.473505938494647e-05
# BBOX Regression Loss:  0.0003760952912794417
# Classification Loss:  6.428462022926376e-05
# BBOX Regression Loss:  0.0003573176774030226
# Classification Loss:  6.373736593458388e-05
# BBOX Regression Loss:  0.0003403257856484462
# Classification Loss:  6.313071679816675e-05
# BBOX Regression Loss:  0.0003248761684648288
# Classification Loss:  6.247048426156092e-05
# BBOX Regression Loss:  0.00031076799379050956
# Classification Loss:  6.178108774329537e-05
# BBOX Regression Loss:  0.0002978342113102445
# Classification Loss:  6.106830673453249e-05
# BBOX Regression Loss:  0.0002859341304311211
# Classification Loss:  6.034010427969473e-05
# BBOX Regression Loss:  0.0002749485692976301
# Classification Loss:  5.96021315311095e-05
# BBOX Regression Loss:  0.0002647758697022368
# Classification Loss:  5.886250562628601e-05
# BBOX Regression Loss:  0.0002553289509202322
# Classification Loss:  5.8124588910864764e-05
# BBOX Regression Loss:  0.00024653887287243436
# Classification Loss:  5.739761342795264e-05
# BBOX Regression Loss:  0.00024170713510669392
# Classification Loss:  5.668919763447325e-05
# BBOX Regression Loss:  0.000329575592400332
# Classification Loss:  5.621670822088864e-05
# BBOX Regression Loss:  0.00034544961898856424
# Classification Loss:  5.625569158130222e-05
# BBOX Regression Loss:  0.0003437672968007406
# Classification Loss:  5.646279096335808e-05
# BBOX Regression Loss:  0.0003363726660861387
# Classification Loss:  5.664230691581511e-05
# BBOX Regression Loss:  0.000327697407975205
# Classification Loss:  5.6726390091830466e-05
# BBOX Regression Loss:  0.0003189362065050219
# Classification Loss:  5.672002525486573e-05
# BBOX Regression Loss:  0.0003104470091167806
# Classification Loss:  5.663329058581286e-05
# BBOX Regression Loss:  0.00030233139541579774
# Classification Loss:  5.648066425881192e-05
# BBOX Regression Loss:  0.00029460388880109696
# Classification Loss:  5.6269977167460994e-05
# BBOX Regression Loss:  0.00028725226787573607
# Classification Loss:  5.601198584945114e-05
# BBOX Regression Loss:  0.00028025487373769674
# Classification Loss:  5.5717926576747046e-05
# BBOX Regression Loss:  0.000273589113583823
# Classification Loss:  5.5389850017675436e-05
# BBOX Regression Loss:  0.0002672325609778098
# Classification Loss:  5.5037173189858134e-05
# BBOX Regression Loss:  0.0002611644597213517
# Classification Loss:  5.466715253964819e-05
# BBOX Regression Loss:  0.0002553656918524122
# Classification Loss:  5.428063035501865e-05
# BBOX Regression Loss:  0.0002498191309468425
# Classification Loss:  5.388067924266084e-05
# BBOX Regression Loss:  0.00024459220070932407
# Classification Loss:  5.346648424417603e-05
# BBOX Regression Loss:  0.0002653918122301017
# Classification Loss:  5.3067891686050984e-05
# BBOX Regression Loss:  0.00028420146241173416
# Classification Loss:  5.2854551659870216e-05
# BBOX Regression Loss:  0.00028572960180406006
# Classification Loss:  5.276512216638636e-05
# BBOX Regression Loss:  0.0002821318606008351
# Classification Loss:  5.2701517907103165e-05
# BBOX Regression Loss:  0.0002774977889218224
# Classification Loss:  5.26138690122512e-05
# BBOX Regression Loss:  0.000272525924510888
# Classification Loss:  5.2494322978725466e-05
# BBOX Regression Loss:  0.0002675762195844851
# Classification Loss:  5.234072728412141e-05
# BBOX Regression Loss:  0.00026275221328855554
# Classification Loss:  5.215593460031632e-05
# BBOX Regression Loss:  0.00025807759065202013
# Classification Loss:  5.19439972266949e-05
# BBOX Regression Loss:  0.0002535587055810256
# Classification Loss:  5.17086211236132e-05
# BBOX Regression Loss:  0.000249192507424225
# Classification Loss:  5.145368295915587e-05
# BBOX Regression Loss:  0.0002449730770406334
# Classification Loss:  5.118128494578791e-05
# BBOX Regression Loss:  0.00024089361267066501
# Classification Loss:  5.0894478220998504e-05
# BBOX Regression Loss:  0.00023694777029184061
# Classification Loss:  5.059689554794673e-05
# BBOX Regression Loss:  0.00023315597960187537
# Classification Loss:  5.0289243495307656e-05
# BBOX Regression Loss:  0.00024182809080836403
# Classification Loss:  4.9978701385731275e-05
# BBOX Regression Loss:  0.0002808872652248919
# Classification Loss:  4.983004872445707e-05
# BBOX Regression Loss:  0.00028609156005086466
# Classification Loss:  4.986848586644881e-05
# BBOX Regression Loss:  0.00028472146253745234
# Classification Loss:  4.9952746240378226e-05
# BBOX Regression Loss:  0.00028146574247906803
# Classification Loss:  5.002626732214173e-05
# BBOX Regression Loss:  0.00027766752265821564
# Classification Loss:  5.0055149593644154e-05
# BBOX Regression Loss:  0.0002737758215690112
# Classification Loss:  5.004555706816594e-05
# BBOX Regression Loss:  0.00026991604915517286
# Classification Loss:  4.999714553671539e-05
# BBOX Regression Loss:  0.0002661353626785884
# Classification Loss:  4.9916890740829885e-05
# BBOX Regression Loss:  0.0002624488743390523
# Classification Loss:  4.980968840328264e-05
# BBOX Regression Loss:  0.00025885927904010115
# Classification Loss:  4.967908941507944e-05
# BBOX Regression Loss:  0.0002553650794075443
# Classification Loss:  4.95257320346775e-05
# BBOX Regression Loss:  0.0002519633072448796
# Classification Loss:  4.93539763085636e-05
# BBOX Regression Loss:  0.0002486506989032766
# Classification Loss:  4.9165710371140154e-05
# BBOX Regression Loss:  0.00024542392685528516
# Classification Loss:  4.896541923900933e-05
# BBOX Regression Loss:  0.00024227973652292143
# Classification Loss:  4.8754708832598596e-05
# BBOX Regression Loss:  0.00023921497523904568
# Classification Loss:  4.853489138517813e-05
# BBOX Regression Loss:  0.00023622775389494816
# Classification Loss:  4.830578962961833e-05
# BBOX Regression Loss:  0.00023367073919580784
# Classification Loss:  4.806952439435933e-05
# BBOX Regression Loss:  0.0002633560001263837
# Classification Loss:  4.787166159542811e-05
# BBOX Regression Loss:  0.0002738480545476587
# Classification Loss:  4.7863407466944604e-05
# BBOX Regression Loss:  0.0002754501416403862
# Classification Loss:  4.7939542740110364e-05
# BBOX Regression Loss:  0.00027386331232817467
# Classification Loss:  4.802773461102919e-05
# BBOX Regression Loss:  0.0002712920378407991
# Classification Loss:  4.8094181846073224e-05
# BBOX Regression Loss:  0.0002683979261046737
# Classification Loss:  4.813276285209672e-05
# BBOX Regression Loss:  0.0002654326839876142
# Classification Loss:  4.813858756312618e-05
# BBOX Regression Loss:  0.00026248336175350566
# Classification Loss:  4.811410947586167e-05
# BBOX Regression Loss:  0.0002595808085693777
# Classification Loss:  4.8062477582766684e-05
# BBOX Regression Loss:  0.0002567350133597352
# Classification Loss:  4.79889828158337e-05
# BBOX Regression Loss:  0.000253948567992186
# Classification Loss:  4.789566264252348e-05
# BBOX Regression Loss:  0.00025122109538178346
# Classification Loss:  4.778328002662309e-05
# BBOX Regression Loss:  0.0002485511237811342
# Classification Loss:  4.765597547105769e-05
# BBOX Regression Loss:  0.00024593711870102996
# Classification Loss:  4.751731545372084e-05
# BBOX Regression Loss:  0.00024337735844768448
# Classification Loss:  4.736546564985205e-05
# BBOX Regression Loss:  0.0002408701932869777
# Classification Loss:  4.720517632250296e-05
# BBOX Regression Loss:  0.0002384140711325369
# Classification Loss:  4.703471449767651e-05
# BBOX Regression Loss:  0.0002360074773858595
# Classification Loss:  4.6856404242781366e-05
# BBOX Regression Loss:  0.00023365114645351541
# Classification Loss:  4.66714170244005e-05
# BBOX Regression Loss:  0.000141167632022256
# Classification Loss:  2.758767869737413e-05
# BBOX Regression Loss:  0.0013341430841777495
# Classification Loss:  3.079749919750072e-05
# BBOX Regression Loss:  0.0010812287396950039
# Classification Loss:  3.625257515612943e-05
# BBOX Regression Loss:  0.0008630880242957641
# Classification Loss:  3.993003456680863e-05
# BBOX Regression Loss:  0.0007071719666931095
# Classification Loss:  4.1987984268753615e-05
# BBOX Regression Loss:  0.0005943366076965582
# Classification Loss:  4.29374200326425e-05
# BBOX Regression Loss:  0.000511046729313358
# Classification Loss:  4.324585041671833e-05
# BBOX Regression Loss:  0.0004477156308608014
# Classification Loss:  4.314923727953875e-05
# BBOX Regression Loss:  0.00039815449540564637
# Classification Loss:  4.280643698609905e-05
# BBOX Regression Loss:  0.0003584156033011149
# Classification Loss:  4.232592052883572e-05
# BBOX Regression Loss:  0.0003258720633633434
# Classification Loss:  4.1769490097508285e-05
# BBOX Regression Loss:  0.0002987410118441436
# Classification Loss:  4.1159361968805756e-05
# BBOX Regression Loss:  0.00027577902819368906
# Classification Loss:  4.0531090521744514e-05
# BBOX Regression Loss:  0.00025609573939746233
# Classification Loss:  3.98904558212038e-05
# BBOX Regression Loss:  0.00023922150767820884
# Classification Loss:  3.925135106216243e-05
# BBOX Regression Loss:  0.0003161040014814657
# Classification Loss:  3.877221434204666e-05
# BBOX Regression Loss:  0.0004793827692589406
# Classification Loss:  4.0326243132547617e-05
# BBOX Regression Loss:  0.0005055707995065878
# Classification Loss:  4.200690077165517e-05
# BBOX Regression Loss:  0.0004960840543215446
# Classification Loss:  4.358384576689663e-05
# BBOX Regression Loss:  0.00047691155712300317
# Classification Loss:  4.486048663104023e-05
# BBOX Regression Loss:  0.00045615284232712486
# Classification Loss:  4.58023535511481e-05
# BBOX Regression Loss:  0.00043609487420548344
# Classification Loss:  4.646059639927513e-05
# BBOX Regression Loss:  0.00041738984393646384
# Classification Loss:  4.6884648849806736e-05
# BBOX Regression Loss:  0.0004001051982810128
# Classification Loss:  4.7128767143061125e-05
# BBOX Regression Loss:  0.0003841542280190845
# Classification Loss:  4.7218393396448204e-05
# BBOX Regression Loss:  0.000369409944118811
# Classification Loss:  4.719118786673261e-05
# BBOX Regression Loss:  0.0003557489153102615
# Classification Loss:  4.707910069385838e-05
# BBOX Regression Loss:  0.0003430590280563063
# Classification Loss:  4.688545509620949e-05
# BBOX Regression Loss:  0.00033124186431821186
# Classification Loss:  4.6631324641397025e-05
# BBOX Regression Loss:  0.0003202108041717638
# Classification Loss:  4.63306756667149e-05
# BBOX Regression Loss:  0.0003098902168885496
# Classification Loss:  4.599584331079481e-05
# BBOX Regression Loss:  0.0003002194477892949
# Classification Loss:  4.563356439272563e-05
# BBOX Regression Loss:  0.0002938392574465942
# Classification Loss:  4.525505733811093e-05
# BBOX Regression Loss:  0.0003186150427869954
# Classification Loss:  4.497875575146644e-05
# BBOX Regression Loss:  0.00031779121728355654
# Classification Loss:  4.4802181304447234e-05
# ...
# BBOX Regression Loss:  1.5312549603902887e-05
# Classification Loss:  1.6819652846671074e-10
# BBOX Regression Loss:  1.4663733595885966e-05
# Classification Loss:  1.605512317182239e-10
# BBOX Regression Loss:  1.4046689760132153e-05
# Classification Loss:  1.5357074338264893e-10
# BBOX Regression Loss:  1.354480697820556e-05
# Classification Loss:  2.943439248167438e-10
# BBOX Regression Loss:  1.521182405445466e-05
# Classification Loss:  2.8257016782407407e-10
# BBOX Regression Loss:  1.5722559983985522e-05
# Classification Loss:  2.7170208444622505e-10
# BBOX Regression Loss:  1.5481027016236223e-05
# Classification Loss:  2.6163904428155003e-10
# BBOX Regression Loss:  1.5044048079347238e-05
# Classification Loss:  2.522947927000661e-10
# BBOX Regression Loss:  1.4570224121014325e-05
# Classification Loss:  2.435949722621328e-10
# BBOX Regression Loss:  1.4100687971065018e-05
# Classification Loss:  2.3547513985339507e-10
# BBOX Regression Loss:  1.3682426938914125e-05
# Classification Loss:  2.2787916760005973e-10
# BBOX Regression Loss:  1.4841553152046397e-05
# Classification Loss:  2.2075794361255785e-10
# BBOX Regression Loss:  1.5781024333772305e-05
# Classification Loss:  3.211024634364478e-10
# BBOX Regression Loss:  1.572633889049038e-05
# Classification Loss:  3.116582733353758e-10
# BBOX Regression Loss:  1.5398345767030226e-05
# Classification Loss:  3.0275375124007936e-10
# BBOX Regression Loss:  1.5016376849776008e-05
# Classification Loss:  2.943439248167438e-10
# BBOX Regression Loss:  1.462673501311958e-05
# Classification Loss:  3.818515781406406e-10
# BBOX Regression Loss:  1.4249283658482915e-05
# Classification Loss:  3.7180285240009746e-10
# BBOX Regression Loss:  1.3924290841267994e-05
# Classification Loss:  5.434041688924501e-10
# BBOX Regression Loss:  1.463295407490848e-05
# Classification Loss:  7.064254195601852e-10
# BBOX Regression Loss:  1.5043093046636591e-05
# Classification Loss:  7.753449726880081e-10
# BBOX Regression Loss:  1.4946511181552258e-05
# Classification Loss:  7.568843781001984e-10
# BBOX Regression Loss:  1.467564066187998e-05
# Classification Loss:  7.392824158187984e-10
# BBOX Regression Loss:  1.438426577297903e-05
# Classification Loss:  7.224805427320076e-10
# BBOX Regression Loss:  1.4108054435491196e-05
# Classification Loss:  7.064254195601852e-10
# BBOX Regression Loss:  1.4609778688008077e-05
# Classification Loss:  6.910683452219203e-10
# BBOX Regression Loss:  1.5267050958383168e-05
# Classification Loss:  6.763647634086879e-10
# BBOX Regression Loss:  1.520166407993954e-05
# Classification Loss:  6.622738308376735e-10
# BBOX Regression Loss:  1.4968241312426809e-05
# Classification Loss:  6.487580383715986e-10
# BBOX Regression Loss:  1.4705158240556355e-05
# Classification Loss:  6.357828776041666e-10
# BBOX Regression Loss:  1.4429028169318556e-05
# Classification Loss:  6.233165466707516e-10
# BBOX Regression Loss:  1.4155782140567374e-05
# Classification Loss:  6.113296900040064e-10
# BBOX Regression Loss:  1.3893212286388665e-05
# Classification Loss:  5.997951675511006e-10
# BBOX Regression Loss:  1.3770652340810458e-05
# Classification Loss:  5.886878496334876e-10
# BBOX Regression Loss:  1.4812714133605869e-05
# Classification Loss:  5.779844341856061e-10
# BBOX Regression Loss:  1.4954285310518303e-05
# Classification Loss:  5.676632835751488e-10
# BBOX Regression Loss:  1.4841615767401038e-05
# Classification Loss:  5.577042786001462e-10
# BBOX Regression Loss:  1.4634074038834069e-05
# Classification Loss:  5.480886875897988e-10
# BBOX Regression Loss:  1.4413591901219353e-05
# Classification Loss:  5.387990488170904e-10
# BBOX Regression Loss:  1.4477648035069625e-05
# Classification Loss:  5.298190646701389e-10
# BBOX Regression Loss:  1.4616729494908725e-05
# Classification Loss:  5.211335062329235e-10
# BBOX Regression Loss:  1.447537651277723e-05
# Classification Loss:  5.127281271001344e-10
# BBOX Regression Loss:  1.4283678069539496e-05
# Classification Loss:  5.045895854001322e-10
# BBOX Regression Loss:  1.4078067647250026e-05
# Classification Loss:  4.967053731282552e-10
# BBOX Regression Loss:  1.3889134616094864e-05
# Classification Loss:  4.890637520032051e-10
# BBOX Regression Loss:  1.4198091392043151e-05
# Classification Loss:  4.816536951546717e-10
# BBOX Regression Loss:  1.4690272042202426e-05
# Classification Loss:  4.744648340329602e-10
# BBOX Regression Loss:  1.4665302611292191e-05
# Classification Loss:  4.674874100030637e-10
# BBOX Regression Loss:  1.4509252301743853e-05
# Classification Loss:  4.6071223014794685e-10
# BBOX Regression Loss:  1.433231815743961e-05
# Classification Loss:  4.5413062686011905e-10
# BBOX Regression Loss:  1.42099102763569e-05
# Classification Loss:  4.477344208480047e-10
# BBOX Regression Loss:  1.4636957011894438e-05
# Classification Loss:  4.415158872251157e-10
# BBOX Regression Loss:  1.4618175455699165e-05
# Classification Loss:  4.354677243864155e-10
# BBOX Regression Loss:  1.4488083502943186e-05
# Classification Loss:  4.295830254082207e-10
# BBOX Regression Loss:  1.4324509652969599e-05
# Classification Loss:  4.238552517361111e-10
# BBOX Regression Loss:  1.4148708133878769e-05
# Classification Loss:  4.182782089501096e-10
# BBOX Regression Loss:  1.4001292646381143e-05
# Classification Loss:  4.1284602441829004e-10
# BBOX Regression Loss:  1.4427968498639254e-05
# Classification Loss:  4.075531266693376e-10
# BBOX Regression Loss:  1.467688535449082e-05
# Classification Loss:  4.02394226331751e-10
# BBOX Regression Loss:  1.4616560523605855e-05
# Classification Loss:  3.9736429850260414e-10
# BBOX Regression Loss:  1.4479480265979948e-05
# Classification Loss:  3.924585664223251e-10
# BBOX Regression Loss:  1.4318729008352177e-05
# Classification Loss:  3.8767248634400406e-10
# BBOX Regression Loss:  1.4152234641623003e-05
# Classification Loss:  3.830017334964859e-10
# BBOX Regression Loss:  1.3988279551810754e-05
# Classification Loss:  3.784421890500992e-10
# BBOX Regression Loss:  1.3849072940724008e-05
# Classification Loss:  4.1554436444716774e-10
# BBOX Regression Loss:  1.444414676255642e-05
# Classification Loss:  4.107124532326658e-10
# BBOX Regression Loss:  1.4855566933770648e-05
# Classification Loss:  4.871899445242656e-10
# BBOX Regression Loss:  1.4861442449420445e-05
# Classification Loss:  4.816536951546717e-10
# BBOX Regression Loss:  1.4754085240558813e-05
# Classification Loss:  4.762418558832709e-10
# BBOX Regression Loss:  1.4610229604335877e-05
# Classification Loss:  4.709502797067901e-10
# BBOX Regression Loss:  1.4457725779890469e-05
# Classification Loss:  4.657750019078144e-10
# BBOX Regression Loss:  1.4303406734943594e-05
# Classification Loss:  4.6071223014794685e-10
# BBOX Regression Loss:  1.4150999313211365e-05
# Classification Loss:  4.5575833520011946e-10
# BBOX Regression Loss:  1.4003057392602179e-05
# Classification Loss:  4.509098422724586e-10
# BBOX Regression Loss:  1.394785274989194e-05
# Classification Loss:  4.4616342288011693e-10
# BBOX Regression Loss:  1.4632570670764162e-05
# Classification Loss:  4.415158872251157e-10
# BBOX Regression Loss:  1.4742369090636801e-05
# Classification Loss:  4.3696417704753723e-10
# BBOX Regression Loss:  1.4675737862628632e-05
# Classification Loss:  4.3250535891439906e-10
# BBOX Regression Loss:  1.4556896050616206e-05
# Classification Loss:  4.281366179152637e-10
# BBOX Regression Loss:  1.4423324063197167e-05
# Classification Loss:  4.5917652271412033e-10
# BBOX Regression Loss:  2.166384931317427e-06
# Classification Loss:  0.0
# BBOX Regression Loss:  2.7726344800342942e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  3.105910849020196e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  2.5676058915754158e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  2.140039733300606e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  1.8059089651850855e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  1.555553991243224e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  1.3650060938735569e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  1.2350908603968994e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  1.4922592245899002e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  1.7824976200370696e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  1.747232946992185e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  1.6476868757210233e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  1.5420992040812312e-05
# Classification Loss:  0.0
# BBOX Regression Loss:  1.443327677844974e-05
# Classification Loss:  2.3547513985339507e-10
# BBOX Regression Loss:  1.3546448276344935e-05
# Classification Loss:  2.2075794361255785e-10
# BBOX Regression Loss:  1.2756797354401356e-05
# Classification Loss:  2.0777218222358387e-10
# BBOX Regression Loss:  1.2108715582696273e-05
# Classification Loss:  1.9622928321116255e-10
# BBOX Regression Loss:  1.6079084886971235e-05
# Classification Loss:  1.8590142620004873e-10
# BBOX Regression Loss:  1.7117955150912097e-05
# Classification Loss:  1.766063548900463e-10
# BBOX Regression Loss:  1.699177796906172e-05
# Classification Loss:  1.6819652846671074e-10
# BBOX Regression Loss:  1.6444341394191712e-05
# Classification Loss:  1.605512317182239e-10
# BBOX Regression Loss:  1.5800516385406777e-05
# Classification Loss:  1.5357074338264893e-10
# BBOX Regression Loss:  1.5165625973483858e-05
# Classification Loss:  1.471719624083719e-10
# BBOX Regression Loss:  1.4568336349637119e-05
# Classification Loss:  1.4128508391203704e-10
# BBOX Regression Loss:  1.4012081476784989e-05
# Classification Loss:  1.3585104222311253e-10
# BBOX Regression Loss:  1.3526573490273796e-05
# Classification Loss:  1.3081952214077501e-10
# BBOX Regression Loss:  1.5204706036361588e-05
# Classification Loss:  1.2614739635003305e-10
# BBOX Regression Loss:  1.6304263151390217e-05
# Classification Loss:  1.217974861310664e-10
# BBOX Regression Loss:  1.6257517461495067e-05
# Classification Loss:  1.1773756992669753e-10
# BBOX Regression Loss:  1.589435337214665e-05
# Classification Loss:  1.1393958380002986e-10
# BBOX Regression Loss:  1.5453031800344915e-05
# Classification Loss:  1.1037897180627893e-10
# BBOX Regression Loss:  1.5003528426137007e-05
# Classification Loss:  1.0703415447881593e-10
# BBOX Regression Loss:  1.4569730004111392e-05
# Classification Loss:  1.0388609111179194e-10
# BBOX Regression Loss:  1.4159719683799486e-05
# Classification Loss:  1.0091791708002645e-10
# BBOX Regression Loss:  1.3972520760348424e-05
# Classification Loss:  9.811464160558127e-11
# BBOX Regression Loss:  1.632070617478138e-05
# Classification Loss:  9.546289453516015e-11
# BBOX Regression Loss:  1.682766413688818e-05
# Classification Loss:  9.295071310002436e-11
# BBOX Regression Loss:  1.665667520472885e-05
# Classification Loss:  9.056736148207502e-11
# BBOX Regression Loss:  1.6331264975225098e-05
# Classification Loss:  8.830317744502314e-11
# BBOX Regression Loss:  1.597003269273182e-05
# Classification Loss:  8.614944140977867e-11
# BBOX Regression Loss:  1.5603528808257355e-05
# Classification Loss:  8.409826423335537e-11
# BBOX Regression Loss:  1.5244623266167548e-05
# Classification Loss:  8.214249064653316e-11
# BBOX Regression Loss:  1.4900123109179075e-05
# Classification Loss:  1.605512317182239e-10
# BBOX Regression Loss:  1.4569563839086747e-05
# Classification Loss:  1.5698342656893003e-10
# BBOX Regression Loss:  1.425327863586244e-05
# Classification Loss:  3.0714148676529786e-10
# BBOX Regression Loss:  1.396544699553314e-05
# Classification Loss:  3.006065615149724e-10
# BBOX Regression Loss:  1.5015357855956096e-05
# Classification Loss:  2.943439248167438e-10
# BBOX Regression Loss:  1.5874832226236652e-05
# Classification Loss:  2.8833690594293273e-10
# BBOX Regression Loss:  1.589134888690246e-05
# Classification Loss:  2.8257016782407407e-10
# BBOX Regression Loss:  1.569007507892e-05
# Classification Loss:  2.7702957629811185e-10
# BBOX Regression Loss:  1.5428649221888613e-05
# Classification Loss:  2.7170208444622505e-10
# BBOX Regression Loss:  1.5151444140080824e-05
# Classification Loss:  2.665756300227114e-10
# BBOX Regression Loss:  1.487631666978048e-05
# Classification Loss:  2.6163904428155003e-10
# BBOX Regression Loss:  1.4609819432782557e-05
# Classification Loss:  2.5688197074915823e-10
# BBOX Regression Loss:  1.4446923303749388e-05
# Classification Loss:  3.1536849087508265e-10
# BBOX Regression Loss:  1.5955075764048395e-05
# Classification Loss:  3.0983571033341454e-10
# BBOX Regression Loss:  1.6207001161753988e-05
# Classification Loss:  3.04493715327666e-10
# BBOX Regression Loss:  1.612478683576731e-05
# Classification Loss:  2.993328048983835e-10
# BBOX Regression Loss:  1.591780068932666e-05
# Classification Loss:  2.943439248167438e-10
# BBOX Regression Loss:  1.568293095979033e-05
# Classification Loss:  2.8951861457384635e-10
# BBOX Regression Loss:  1.543824537433984e-05
# Classification Loss:  2.8484895950007465e-10
# BBOX Regression Loss:  1.5196411751552335e-05
# Classification Loss:  2.8032754744451793e-10
# BBOX Regression Loss:  1.4960198949989893e-05
# Classification Loss:  2.759474295156973e-10
# BBOX Regression Loss:  1.4730502068635379e-05
# Classification Loss:  2.7170208444622505e-10
# BBOX Regression Loss:  1.4507525904475067e-05
# Classification Loss:  2.675853861970398e-10
# BBOX Regression Loss:  1.429190988706842e-05
# Classification Loss:  4.2174651914040903e-10
# BBOX Regression Loss:  1.4251631706292923e-05
# Classification Loss:  5.194304555589596e-10
# BBOX Regression Loss:  1.5517843920584853e-05
# Classification Loss:  5.630927257363795e-10
# BBOX Regression Loss:  1.5695622701834827e-05
# Classification Loss:  5.550485439401455e-10
# BBOX Regression Loss:  1.5606280791782315e-05
# Classification Loss:  5.472309588142279e-10
# BBOX Regression Loss:  1.5432865976602998e-05
# Classification Loss:  5.39630528830697e-10
# BBOX Regression Loss:  1.5236134190352335e-05
# Classification Loss:  5.32238329805619e-10
# BBOX Regression Loss:  1.5035989556106439e-05
# Classification Loss:  5.250459199433808e-10
# BBOX Regression Loss:  1.4837675774495094e-05
# Classification Loss:  5.180453076774691e-10
# BBOX Regression Loss:  1.4643214744211624e-05
# Classification Loss:  5.11228922050134e-10
# BBOX Regression Loss:  1.4453452830898959e-05
# Classification Loss:  5.045895854001322e-10
# BBOX Regression Loss:  1.4271578562374842e-05
# Classification Loss:  5.434041688924501e-10
# BBOX Regression Loss:  1.4430985026268594e-05
# Classification Loss:  5.365256351090014e-10
# BBOX Regression Loss:  1.534179555954835e-05
# Classification Loss:  5.298190646701389e-10
# BBOX Regression Loss:  1.5402182660857762e-05
# Classification Loss:  5.232780885631001e-10
# BBOX Regression Loss:  1.5305403541497652e-05
# Classification Loss:  5.168966484586721e-10
# BBOX Regression Loss:  1.5155375541930747e-05
# Classification Loss:  5.106689779953146e-10
# BBOX Regression Loss:  1.4986082821052386e-05
# Classification Loss:  5.045895854001322e-10
# BBOX Regression Loss:  1.481357176523044e-05
# Classification Loss:  4.986532373366013e-10
# BBOX Regression Loss:  1.4643951564046746e-05
# Classification Loss:  4.928549438791989e-10
# BBOX Regression Loss:  1.4512866167029581e-05
# Classification Loss:  4.871899445242656e-10
# BBOX Regression Loss:  1.5267632914475327e-05
# Classification Loss:  4.816536951546717e-10
# BBOX Regression Loss:  1.5423023914601583e-05
# Classification Loss:  4.762418558832709e-10
# BBOX Regression Loss:  1.5373876857924493e-05
# Classification Loss:  4.709502797067901e-10
# BBOX Regression Loss:  1.5249904751109258e-05
# Classification Loss:  4.657750019078144e-10
# BBOX Regression Loss:  1.5097642426612575e-05
# Classification Loss:  4.6071223014794685e-10
# BBOX Regression Loss:  1.4941490585633305e-05
# Classification Loss:  4.5575833520011946e-10
# BBOX Regression Loss:  1.4785193821995602e-05
# Classification Loss:  4.509098422724586e-10
# BBOX Regression Loss:  1.4636719624179946e-05
# Classification Loss:  4.4616342288011693e-10
# BBOX Regression Loss:  1.4760286346524899e-05
# Classification Loss:  4.415158872251157e-10
# BBOX Regression Loss:  1.4908781580703424e-05
# Classification Loss:  4.3696417704753723e-10
# BBOX Regression Loss:  1.4837869043728073e-05
# Classification Loss:  4.3250535891439906e-10
# BBOX Regression Loss:  1.471681156481691e-05
# Classification Loss:  4.281366179152637e-10
# BBOX Regression Loss:  1.4580238785115883e-05
# Classification Loss:  4.238552517361111e-10
# OK
